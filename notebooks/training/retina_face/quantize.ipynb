# %%
from retinaface import RetinaFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\JoshFile\Github\spoofing-recognition\.venv\Lib\site-packages\retinaface\commons\package_utils.py:19, in validate_for_keras3()
#      18 try:
# ---> 19     import tf_keras
#      21     logger.debug(f"tf_keras is already available - {tf_keras.__version__}")
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from retinaface import RetinaFace
#
# File d:\JoshFile\Github\spoofing-recognition\.venv\Lib\site-packages\retinaface\RetinaFace.py:20
#      17 from retinaface.commons import package_utils
#      19 # users should install tf_keras package if they are using tf 2.16 or later versions
# ---> 20 package_utils.validate_for_keras3()
# ...

# %%
from src.spoofdet.verify_memory import print_memory_usage
print_memory_usage("start")
resp = RetinaFace.detect_faces("debug_image.jpg")
print_memory_usage("after detection")
